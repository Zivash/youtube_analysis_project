# %% [markdown]
# # EDA

# %% [markdown]
# Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# Reading the data

# %%
df = pd.read_csv("Final Clean.csv")
df
# Out:
#       Unnamed: 0  Song Name  Published Date  Published Time  Duartion Time  \
# 0              0          0            2010              22           3.52
# 1              1          1            2010               8           3.67
# 2              2          2            2010              19           4.45
# 3              3          3            2010              23           3.90
# 4              4          4            2010              21           3.95
# ...          ...        ...             ...             ...            ...
# 4345        6494       6494            2022               5           4.62
# 4346        6495       6495            2022               4           4.17
# 4347        6496       6496            2022              20           4.20
# 4348        6498       6498            2022               9           3.63
# 4349        6499       6499            2021               6           4.97
#
#            Views       Likes   Comments  Language  Countries Allowed  \
# 0     3430156734  20107995.0  1278511.0         7                249
# 1     2895467607  23119219.0  4804685.0         7                246
# 2     2528503555  12643828.0   598598.0         7                249
# 3     2148871172  11532107.0   411271.0         7                249
# 4     1786407074   7625136.0   242499.0         7                249
# ...          ...         ...        ...       ...                ...
# 4345    50187927    401459.0    11062.0        32                249
# 4346    50066892    656326.0    16227.0         5                249
# 4347    50030052    315787.0     6105.0         9                249
# 4348    49972834   1169928.0    50333.0        20                249
# 4349  1277115367  10436212.0   339388.0        14                249
#
#       Channel Name  Channel Country  Channel Published Date  Subscribes  \
# 0             1055               45                  2009.0    18400000
# 1              427               45                  2009.0    31700000
# 2              278               31                  2009.0    24800000
# 3               29               31                  2009.0    15100000
# 4              145               31                  2006.0    36000000
# ...            ...              ...                     ...         ...
# 4345          1036               45                  2018.0      504000
# 4346           951               19                  2014.0    22400000
# 4347           362                2                  2009.0      747000
# 4348           764               19                  2006.0    31300000
# 4349           846               19                  2006.0   233000000
#
#       Video Count   Total Views
# 0             191  2.360025e+10
# 1             204  2.593110e+10
# 2             104  1.958296e+10
# 3              52  1.190144e+10
# 4              99  1.832933e+10
# ...           ...           ...
# 4345           39  2.092406e+08
# 4346         5288  1.027827e+10
# 4347          351  3.069123e+08
# 4348         4054  2.622516e+10
# 4349        18465  2.120000e+11
#
# [4350 rows x 16 columns]

# %%
df['Published Date'].hist(bins=13, grid = False, rwidth=0.9, color ='darkblue')
plt.xlabel('Published Date')
plt.ylabel('Video')
plt.title('Videos per year')
plt.show()

# %%
k=df.groupby(['Views']).mean()[['Likes','Comments']]
k.plot()
# Out:
# <AxesSubplot:xlabel='Views'>

# %%
df.Views.hist(bins=200,color = 'green')
plt.xlabel('Views')
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\USER\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
value_counts = df['Language'].value_counts()
plt.pie([value_counts[7], df.shape[0]-value_counts[7]], labels=['English', 'Other Languages'],colors = ['red','orange'],  startangle=90, autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %%
df["Duartion Time"].hist(bins=50,color='lightblue')
plt.xlabel('Duartion Time')
plt.title('Duartion Time Frequency')
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\USER\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
sns.scatterplot(x = 'Channel Published Date', y = 'Subscribes',s=50,color = 'purple',data = df)
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\USER\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
grouped = df.groupby("Published Date").mean()
grouped.plot(kind='bar', y='Views',color = 'brown')
plt.title("Average Number of Views per Year")
plt.xlabel("Year")
plt.ylabel("Number of Views")
plt.show()

# %%
df2 = pd.DataFrame(df, columns = ['Views','Likes', 'Comments', 'Video Count'])
sns.heatmap(df2.corr(), annot=True, cmap='Greens')
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure(figsize=(8,3))
sns.boxplot(df["Countries Allowed"])
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Countries Allowed'>
